# %% [markdown]
# ## Pre-Implementation: Data Cleaning
# *    I. Categorizing Records According to Phrase Length
# *    II. Finding Total Number of Unique Words

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### A. JUMLA-QSL-22

# %%
df = pd.read_excel("Dataset Excel Sheets/Full Dataset Corrected.xlsx")

# %%
df
# Out:
#      CODE         INTENT_ENGLISH                      INTENT_ARABIC
# 0      59               GREETING                              مرحبا
# 1      60            CORONA_TEST                   فيروس كورونا فحص
# 2      61               GREETING                              مرحبا
# 3      62         DOCTOR_REQUEST                     اريد طبيب رؤية
# 4      63               NEGATION                       موعد لا مافي
# ..    ...                    ...                                ...
# 896   960  CERTIFICATION_REQUEST                   اريد شهادة تقرير
# 897   961       ANALYSIS_REQUEST                 مرحبا اريد ضغط فحص
# 898   962       ANALYSIS_REQUEST        السلام عليكم اريد فحص الغدة
# 899   963       ANALYSIS_REQUEST        السلام عليكم اريد الغدة فحص
# 900   964            CORONA_TEST  السلام عليكم اريد فيروس كرونة فحص
#
# [901 rows x 3 columns]

# %% [markdown]
# ### I. Categorizing Records According to Phrase Length

# %%
# Assuming df is your original DataFrame
# Initialize empty lists to collect data
unique_records = []
code_lists = []
phrase_lengths = []
record_counts = []

# Iterate over the 'INTENT_ARABIC' column
for idx, record in enumerate(df['INTENT_ARABIC']):
    record = record.strip()     # trim trailing whitespaces
    
    recordWords = record.split()
    recordWordsCount = len(recordWords)
    recordCode = df.at[idx, 'CODE']
    
    # Check if the record is already in the list of unique_records
    if record not in unique_records:
        unique_records.append(record)
        code_lists.append([recordCode])
        phrase_lengths.append(recordWordsCount)  # Store the length directly as an integer
        record_counts.append(1)
    else:
        # Find the index of the existing record
        record_index = unique_records.index(record)
        # Update the corresponding lists
        code_lists[record_index].append(recordCode)
        # No need to append to phrase_lengths, it's already a single integer
        record_counts[record_index] += 1

# Create a new DataFrame from the collected data
result_df = pd.DataFrame({
    'INTENT_ARABIC': unique_records,
    'CODE': code_lists,
    'PHRASE_LENGTH': phrase_lengths,
    'COUNT': record_counts
})

# Export the resulting DataFrame to an Excel file
result_df.to_excel('Dataset Excel Sheets/Categorized Records.xlsx', index=False)

# %% [markdown]
# ### II. Finding Total Number of Unique Words

# %%
df2 = pd.read_excel("Dataset Excel Sheets/Categorized Records.xlsx")

# %%
df2            # total unique records
# Out:
#                           INTENT_ARABIC  \
# 0                                 مرحبا
# 1                      فيروس كورونا فحص
# 2                        اريد طبيب رؤية
# 3                          موعد لا مافي
# 4                           اريد  موافق
# ..                                  ...
# 339                اﻷشارة سريعة مش فاهم
# 340  السلام عليكم اريد سكر دم و ضغط فحص
# 341              لا اريد الساعة السادسة
# 342                      نعم مناسب شكرا
# 343            مرحبا اريد حجز موعد قريب
#
#                                                   CODE  PHRASE_LENGTH  COUNT
# 0    [59, 61, 68, 76, 83, 93, 99, 106, 108, 110, 11...              1     47
# 1                                                 [60]              3      1
# 2                                                 [62]              3      1
# 3                                                 [63]              3      1
# 4                                                 [64]              2      1
# ..                                                 ...            ...    ...
# 339                                              [875]              4      1
# 340                                              [881]              8      1
# 341                                              [946]              4      1
# 342                                              [951]              3      1
# 343                                              [953]              5      1
#
# [344 rows x 4 columns]

# %%
# Initialize an empty list to collect unique words
unique_words = set()

# Iterate through each unique record
for record in df2['INTENT_ARABIC']:
    words = record.split()
    unique_words.update(words)

# Convert the set of unique words back to a list
unique_words_list = list(unique_words)

# Create a DataFrame with the list of unique words
unique_words_df = pd.DataFrame({'UNIQUE_WORDS': unique_words_list})     # 159 words

# Export the DataFrame to an Excel file
unique_words_df.to_excel('Dataset Excel Sheets/Unique Words.xlsx', index=False)

# %% [markdown]
# ### B. ArabSign

# %%
df = pd.read_excel("Dataset Excel Sheets/ArabSign Records.xlsx")

# %%
df
# Out:
#     SentenceID                         Sentence
# 0            1                         اسم الله
# 1            2                       الحمد الله
# 2            3          جميع الصم العرب  السامع
# 3            4      السلام عليكم رحمة الله بركة
# 4            5       اليوم اقدم انتم برنامج اخر
# 5            6  موضوع دراسة لغة الاشارة العربية
# 6            7      كلمات اليوم متفرقة في الدين
# 7            8                 ايضا كلمات عادية
# 8            9                      لا شرك الله
# 9           10                        الله اكبر
# 10          11                  لا شرك الله احد
# 11          12                العبادة الله واحد
# 12          13                        الله كريم
# 13          14                         الله رزق
# 14          15                 ايضا كلمات مختلف
# 15          16                   كلنا فقير الله
# 16          17                         الله غني
# 17          18            الله يساعد جميع الناس
# 18          19                  الحياة خلق الله
# 19          20                   لمن جميع الناس
# 20          21             الله خلق الناس عبادة
# 21          22                        شكرا انتم
# 22          23                 ترحيب انتم دائما
# 23          24   ايضا تمني اشارة-هو التعاون لكم
# 24          25   تعليم لغة الاشارة مع الامائيات
# 25          26         انا حب تعليم لغة الاشارة
# 26          27                          انا سفر
# 27          28                     اين السعودية
# 28          29             غدا احتمال في امتحان
# 29          30            الجسم تفاعل مع الكلمة
# 30          31   الصم تمني اشارة-هم جميع السامع
# 31          32              تفاعل مع الصم تواصل
# 32          33                   تفاعل الجسم مع
# 33          34                        هنا نكتفي
# 34          35                   الله لقاء انتم
# 35          36                    الله قبول عمل
# 36          37                  تمني الله فائدة
# 37          38                    نحن انتم جميع
# 38          39                         كلمة اول
# 39          40                        الله اعوذ
# 40          41                       نصائح طبية
# 41          42              موضوع فايروس كورونا
# 42          43                     الجزء الثاني
# 43          44                      يوم القيامة
# 44          45                      الصلة الخمس
# 45          46                      خطبة الجمعة
# 46          47                لقاء غدا اسم الله
# 47          48                     استمرار انتم
# 48          49                        الله اعلم
# 49          50               اكتساب لغة الاشارة

# %% [markdown]
# ### I. Categorizing Records According to Phrase Length

# %%
unique_records = []
code_lists = []
phrase_lengths = []

# Iterate over the 'Sentence' column
for idx, record in enumerate(df['Sentence']):
    record = record.strip()     # trim trailing whitespaces
    
    recordWords = record.split()
    recordWordsCount = len(recordWords)
    recordCode = df.at[idx, 'SentenceID']
    
    # Check if the record is already in the list of unique_records
    if record not in unique_records:
        unique_records.append(record)
        code_lists.append([recordCode])
        phrase_lengths.append(recordWordsCount)  # Store the length directly as an integer
    else:
        # Find the index of the existing record
        record_index = unique_records.index(record)
        # Update the corresponding lists
        code_lists[record_index].append(recordCode)

# Create a new DataFrame from the collected data
result_df = pd.DataFrame({
    'Sentence': unique_records,
    'ID': code_lists,
    'PHRASE_LENGTH': phrase_lengths,
})

# Export the resulting DataFrame to an Excel file
result_df.to_excel('Dataset Excel Sheets/Categorized Records.xlsx', index=False)

# %% [markdown]
# ### II. Finding Total Number of Unique Words

# %%
df2 = pd.read_excel("Dataset Excel Sheets/Categorized Records.xlsx")

# %%
df2
# Out:
#                            Sentence    ID  PHRASE_LENGTH
# 0                          اسم الله   [1]              2
# 1                        الحمد الله   [2]              2
# 2                         الله اكبر  [10]              2
# 3                         الله كريم  [13]              2
# 4                          الله رزق  [14]              2
# 5                          الله غني  [17]              2
# 6                         شكرا انتم  [22]              2
# 7                           انا سفر  [27]              2
# 8                      اين السعودية  [28]              2
# 9                         هنا نكتفي  [34]              2
# 10                         كلمة اول  [39]              2
# 11                        الله اعوذ  [40]              2
# 12                       نصائح طبية  [41]              2
# 13                     الجزء الثاني  [43]              2
# 14                      يوم القيامة  [44]              2
# 15                      الصلة الخمس  [45]              2
# 16                      خطبة الجمعة  [46]              2
# 17                     استمرار انتم  [48]              2
# 18                        الله اعلم  [49]              2
# 19                 ايضا كلمات عادية   [8]              3
# 20                      لا شرك الله   [9]              3
# 21                العبادة الله واحد  [12]              3
# 22                 ايضا كلمات مختلف  [15]              3
# 23                   كلنا فقير الله  [16]              3
# 24                  الحياة خلق الله  [19]              3
# 25                   لمن جميع الناس  [20]              3
# 26                 ترحيب انتم دائما  [23]              3
# 27                   تفاعل الجسم مع  [33]              3
# 28                   الله لقاء انتم  [35]              3
# 29                    الله قبول عمل  [36]              3
# 30                  تمني الله فائدة  [37]              3
# 31                    نحن انتم جميع  [38]              3
# 32              موضوع فايروس كورونا  [42]              3
# 33               اكتساب لغة الاشارة  [50]              3
# 34          جميع الصم العرب  السامع   [3]              4
# 35                  لا شرك الله احد  [11]              4
# 36            الله يساعد جميع الناس  [18]              4
# 37             الله خلق الناس عبادة  [21]              4
# 38             غدا احتمال في امتحان  [29]              4
# 39            الجسم تفاعل مع الكلمة  [30]              4
# 40              تفاعل مع الصم تواصل  [32]              4
# 41                لقاء غدا اسم الله  [47]              4
# 42      السلام عليكم رحمة الله بركة   [4]              5
# 43       اليوم اقدم انتم برنامج اخر   [5]              5
# 44  موضوع دراسة لغة الاشارة العربية   [6]              5
# 45      كلمات اليوم متفرقة في الدين   [7]              5
# 46   ايضا تمني اشارة-هو التعاون لكم  [24]              5
# 47   تعليم لغة الاشارة مع الامائيات  [25]              5
# 48         انا حب تعليم لغة الاشارة  [26]              5
# 49   الصم تمني اشارة-هم جميع السامع  [31]              5

# %%
# Initialize an empty list to collect unique words
unique_words = set()

# Iterate through each unique record
for record in df2['Sentence']:
    words = record.split()
    unique_words.update(words)

# Convert the set of unique words back to a list
unique_words_list = list(unique_words)

# Create a DataFrame with the list of unique words
unique_words_df = pd.DataFrame({'UNIQUE_WORDS': unique_words_list})     # 159 words

# Export the DataFrame to an Excel file
unique_words_df.to_excel('Dataset Excel Sheets/Unique Words.xlsx', index=False)
